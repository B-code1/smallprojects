# %% [markdown]
# <a href="https://colab.research.google.com/github/B-code1/smallprojects/blob/master/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
bellah=pd.read_csv('/content/boston-housing-dataset[1].csv')
print("shape of the dataset")
bellah.shape
bellah.head(20)
# Out:
# shape of the dataset
#     Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  \
# 0            0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1
# 1            1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2
# 2            2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2
# 3            3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3
# 4            4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3
# 5            5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3
# 6            6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5
# 7            7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5
# 8            8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5
# 9            9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5
# 10          10  0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5
# ...

# %%
import pandas as pd
bellah=pd.read_csv('/content/boston-housing-dataset[1].csv')
data=bellah.loc[:,['LSTAT','MEDV']]
print(data)
# Out:
#      LSTAT  MEDV
# 0     4.98  24.0
# 1     9.14  21.6
# 2     4.03  34.7
# 3     2.94  33.4
# 4     5.33  36.2
# ..     ...   ...
# 501   9.67  22.4
# 502   9.08  20.6
# 503   5.64  23.9
# 504   6.48  22.0
# 505   7.88  11.9
#
# [506 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

bellah=pd.read_csv('/content/boston-housing-dataset[1].csv')
bellah.plot(x='LSTAT',y='MEDV',style='o')
plt.title('LSTAT vs MEDV')
plt.xlabel('LSTAT')
plt.ylabel('MEDV')
plt.show()

# %%
import pandas as pd
bellah=pd.read_csv('/content/boston-housing-dataset[1].csv')
x=pd.DataFrame(data['LSTAT'])
y=pd.DataFrame(data['MEDV'])

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
bellah=pd.read_csv('/content/boston-housing-dataset[1].csv')
x=pd.DataFrame(data['LSTAT'])
y=pd.DataFrame(data['MEDV'])
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (404, 1)
# (102, 1)
# (404, 1)
# (102, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
print(regressor.intercept_)
# Out:
# [34.76519272]

# %%
print(regressor.coef_)
# Out:
# [[-0.95648761]]

# %%
y_pred=regressor.predict(x_test)
y_pred
# Out:
# array([[27.74457365],
#        [25.64986578],
#        [24.72207279],
#        [15.85543263],
#        [22.96213559],
#        [26.66374265],
#        [23.81340956],
#        [25.87942281],
#        [22.6751893 ],
#        [24.5977294 ],
#        [15.04241816],
#        [14.46852559],
#        [17.7492781 ],
#        [ 7.71572305],
#        [32.92873651],
#        [30.23144144],
#        [24.49251577],
#        [30.86272327],
#        [29.66711375],
#        [26.37679636],
#        [27.87848191],
#        [23.25864675],
#        [21.28828227],
#        [27.88804679],
#        [24.9994542 ],
#        [22.01521285],
#        [21.53696905],
#        [19.66225332],
#        [30.73837988],
#        [18.41881943],
#        [17.51972107],
#        [20.70482482],
#        [25.05684346],
#        [22.90474633],
#        [26.11854471],
#        [20.76221408],
#        [ 9.16001934],
#        [26.27158273],
#        [17.89275124],
#        [11.71384127],
#        [26.55852901],
# ...

# %%
y_test.head(20)
# Out:
#      MEDV
# 329  22.6
# 371  50.0
# 219  23.0
# 403   8.3
# 78   21.2
# 15   19.9
# 487  20.6
# 340  18.7
# 310  16.1
# 102  18.6
# 418   8.8
# 411  17.2
# 446  14.9
# 386  10.5
# 162  50.0
# 299  29.0
# 480  23.0
# 196  33.3
# 175  29.4
# 37   21.0

# %%
from sklearn import metrics
import numpy as np
mae=metrics.mean_absolute_error(y_test,y_pred)
mse=metrics.mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
print("mean absolute error(mae):",mae)
print("mean squared error(mse):",mse)
print("root mean squared error(rmse):",rmse)
# Out:
# mean absolute error(mae): 4.864010561669802
# mean squared error(mse): 46.336305360025925
# root mean squared error(rmse): 6.807077593213252

# %%
import joblib
import pickle
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)
joblib.dump(model,'model_joblib')
# Out:
# ['model_joblib']

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
bellah=pd.read_csv('/content/boston-housing-dataset[1].csv')
x=bellah[['LSTAT']]
y=bellah['MEDV']
regressor=LinearRegression()
regressor.fit(x,y)
bellah.plot(x='LSTAT',y='MEDV',style='o',label='datapoints')
plt.plot(x,regressor.predict(x),color='red', linewidth='2', label='regression line')
plt.title('LSTAT vs MEDV')
plt.xlabel('LSTAT')
plt.ylabel('MEDV')
plt.show()
