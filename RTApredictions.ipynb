# %% [markdown]
# <a href="https://colab.research.google.com/github/B-code1/smallprojects/blob/master/RTApredictions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
bellah=pd.read_csv('/content/dft-road-casualty-statistics-casualty-provisional-mid-year-unvalidated-2023.csv')
print("shape od the dataset",bellah.shape)
bellah.head(20)
# Out:
# shape od the dataset (62674, 19)
#    collision_index  collision_year collision_reference  vehicle_reference  \
# 0    2023010419171            2023           010419171                  1
# 1    2023010419183            2023           010419183                  2
# 2    2023010419183            2023           010419183                  3
# 3    2023010419189            2023           010419189                  1
# 4    2023010419191            2023           010419191                  2
# 5    2023010419192            2023           010419192                  2
# 6    2023010419198            2023           010419198                  1
# 7    2023010419201            2023           010419201                  1
# 8    2023010419205            2023           010419205                  1
# 9    2023010419209            2023           010419209                  1
# 10   2023010419223            2023           010419223                  1
# ...

# %%
import pandas as pd
bellah=pd.read_csv('/content/dft-road-casualty-statistics-casualty-provisional-mid-year-unvalidated-2023.csv')
data=bellah.loc[:,('casualty_severity','age_of_casualty')]
data.head(20)
# Out:
#     casualty_severity  age_of_casualty
# 0                   3               20
# 1                   3               25
# 2                   3               38
# 3                   3               50
# 4                   3               34
# 5                   3               24
# 6                   3               65
# 7                   3               22
# 8                   3               20
# 9                   3               33
# 10                  3               58
# 11                  3               40
# 12                  3               -1
# 13                  3               -1
# 14                  3               56
# 15                  3               44
# 16                  3               42
# 17                  3               20
# 18                  3               49
# 19                  3               28

# %%
import pandas as pd
import matplotlib.pyplot as plt
bellah=pd.read_csv('/content/dft-road-casualty-statistics-casualty-provisional-mid-year-unvalidated-2023.csv')
bellah.plot(kind='scatter',x='casualty_severity',y='age_of_casualty')
plt.title('casualty_severity vs age_of_casualty')
plt.xlabel('casualty_severity')
plt.ylabel('age_of_casualty')
plt.show()

# %%
import pandas as pd
bellah=pd.read_csv('/content/dft-road-casualty-statistics-casualty-provisional-mid-year-unvalidated-2023.csv')
x=pd.DataFrame(bellah['casualty_severity'])
y=pd.DataFrame(bellah['age_of_casualty'])

# %%
from sklearn.model_selection import train_test_split
bellah=pd.read_csv('/content/dft-road-casualty-statistics-casualty-provisional-mid-year-unvalidated-2023.csv')
x=pd.DataFrame(bellah['casualty_severity'])
y=pd.DataFrame(bellah['age_of_casualty'])
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (50139, 1)
# (12535, 1)
# (50139, 1)
# (12535, 1)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
print(regressor.intercept_)
# Out:
# [49.16463478]

# %%
print(regressor.coef_)
# Out:
# [-4.39549316]

# %%
y_test.head(20)
# Out:
#        age_of_casualty
# 1090                28
# 36769               30
# 39703               29
# 57584               40
# 23397               58
# 30091               35
# 28311               32
# 7292                35
# 55335               30
# 34080               21
# 6828                23
# 19308               62
# 22521               21
# 54134               37
# 5808                43
# 27912               22
# 15386               69
# 9660                28
# 56745               35
# 20247               20

# %%
from sklearn import metrics
mae=metrics.mean_absolute_error(y_test,y_pred)
mse=metrics.mean_squared_error(y_test,y_pred)
rmse=np.sqrt(metrics.mean_squared_error(y_test,y_pred))
print("mean absolute error(mae):",mae)
print("mean squared error(mse):",mse)
print("root mean squared error(rmse):",rmse)
# Out:
# mean absolute error(mae): 16.002976638133767
# mean squared error(mse): 386.3028055754116
# root mean squared error(rmse): 19.654587392652424

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
bellah=pd.read_csv('/content/dft-road-casualty-statistics-casualty-provisional-mid-year-unvalidated-2023.csv')
x=bellah[['casualty_severity']]
y=bellah['age_of_casualty']
regressor=LinearRegression()
regressor.fit(x,y)
bellah.plot(style='o',x='casualty_severity',y='age_of_casualty',label='datapoints')
plt.plot(x,regressor.predict(x),color='yellow',linewidth='2')
plt.title('casualty_severity vs age_of_casualty')
plt.xlabel('casualty_severity')
plt.ylabel('age_of_casualty')
plt.legend()
plt.show()

# %%
import joblib
import pickle
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x,y)
joblib.dump(model,'model_joblib pickle')
# Out:
# ['model_joblib pickle']
